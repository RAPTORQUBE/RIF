# %%
import pandas as pd

# %%
file='../100-DL/100-Raw-Zone/0100-External/900-Other/000019-Data-Source-T/Test_Data.csv'

# %%
df = pd.read_csv(file, sep=',',header=0)

# %%
df.shape
# Out:
# (148, 3)

# %%
df2=df.copy(deep=True)

# %%
df2['name2']=df2['name'].astype('category').cat.codes
df2['media2']=df2['media'].astype('category').cat.codes

# %%
df2
# Out:
#       id       name   media  name2  media2
# 0      1       Liam  online    100       0
# 1      2       Noah   print    120       1
# 2      3    William  online    144       0
# 3      4      James  online     71       0
# 4      5     Oliver   print    122       1
# 5      6   Benjamin  online     14       0
# 6      7     Elijah   print     45       1
# 7      8      Lucas  online    104       0
# 8      9      Mason  online    108       0
# 9     10      Logan   print    102       1
# 10    11  Alexander  online      5       0
# 11    12      Ethan   print     47       1
# 12    13      Jacob  online     70       0
# 13    14    Michael  online    115       0
# 14    15     Daniel  online     36       0
# 15    16      Henry   print     60       1
# 16    17    Jackson  online     69       0
# 17    18  Sebastian  online    134       0
# 18    19      Aiden   print      4       1
# 19    20    Matthew  online    110       0
# 20    21     Samuel   print    131       1
# ...

# %%
df2.corr()
# Out:
#               id     name2   media2
# id      1.000000  0.004653 -0.26068
# name2   0.004653  1.000000 -0.03490
# media2 -0.260680 -0.034900  1.00000
